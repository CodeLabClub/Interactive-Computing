# %% [markdown]
# # 6. 画笔几何
# ## 学习目标
# - 编程知识：函数、元组
# - 主题创作：绘制正方形和圆，并进行组合
# - 在创作中实践“试验和迭代”、“测试和调试”

# %% [markdown]
# ## 编程准备
# 打开[课程视频](https://www.bilibili.com/video/BV1SN411Z7ek?p=10)和 [Scratch 创作](https://create.codelab.club/projects/editor/)页面，登陆自己的 CodeLab 账号，这样 Scratch 作品可以及时保存。
#
# #### 编程相关单词
# - square：[skwer]，正方形、平方
# - coordinate：[koʊˈɔːrdɪneɪt]，坐标
# - function：[ˈfʌŋkʃn]，函数、功能
# - define：[dɪˈfaɪn]，定义、规定
# - return：[rɪˈtɜːrn]，返回、归还
# - tuple：[ˈtʌpəl]，元组
# - circle：[ˈsɜːrkl]，圆、圆圈
# - format：[ˈfɔːrmæt]，格式、格式化

# %% [markdown]
# ## 画正方形
# 先体验[画笔几何](https://create.codelab.club/projects/8068/editor/)项目，了解如何使用自制积木让 Scratch 程序模块化，如果第一次接触自制积木，可以先看一下这个[视频](https://www.bilibili.com/video/BV1jT4y1K7iA?p=18)。

# %% [markdown]
# 如果想以原点为中心画一个正方形，应该怎么办呢？
#
# ![image.png](attachment:d2cbfd4f-ec10-4693-b1ae-f4fcea96de42.png)

# %% [markdown]
# 观看视频[画笔几何 1](https://www.bilibili.com/video/BV1SN411Z7ek?p=10)，了解函数和元组，打开[【交互计算】画笔几何](https://create.codelab.club/projects/10002/editor/)项目，然后定义一个画正方形的函数 square1()，并画出正方形。

# %%
from codelab_adapter_client.message import send_message

# %% [markdown]
# 根据画正方形的代码尝试画一个旋转了 45 度的正方形吧，你同样可以定义一个函数。
#
# ![image.png](attachment:283a6f21-c59c-451f-9209-468af85fe6fd.png)

# %% [markdown]
# 正方形和旋转了 45 度的正方形可以组合出更复杂的图案，你甚至可以让两个角色同时画图，编写程序测试一下吧！

# %% [markdown]
# ## 画复杂图案
# 观看视频[画笔几何 2](https://www.bilibili.com/video/BV1SN411Z7ek?p=11)，了解如何画复杂图案。
# ### 画圆
# 计算出圆上点的坐标，那么也可以用类似的方式把圆画出来。如果之前没学过如何计算圆的坐标，这部分的内容不要求掌握，只需了解。
#
# ![image.png](attachment:99a1090c-ff3d-42a9-8138-6d67de4de7df.png)

# %% [markdown]
# 定义一个画圆的函数，把圆画出来。

# %%
from codelab_adapter_client.message import send_message

# %% [markdown]
# ### 画心形
# 用类似的方式可以画出更复杂的图案，比如一个心形。运行以下代码，看看效果吧！
#
# ![image.png](attachment:2bbd9c31-24dc-49ee-9333-89a068562613.png)

# %%
# 画心形
import math
import time
from codelab_adapter_client.message import send_message

def heart(r):
    coordinates = ''
    for i in range(0, 365, 5): 
        # 计算心形坐标
        x = r * (16*math.sin(math.radians(i))**3)
        y = r * (13*math.cos(math.radians(i))-5*math.cos(2*math.radians(i))-2*math.cos(3*math.radians(i))-math.cos(4*math.radians(i)))
        coordinates += '{:.2f},{:.2f},'.format(x, y)
    send_message(coordinates + 'coordinates')
        
heart(6)

# %% [markdown]
# ## 拓展
# 发挥自己的想象，进一步拓展画笔几何的项目，并将作品分享到[【交互计算】画笔几何](https://create.codelab.club/studios/422/)工作室，看看工作室中其他人创作的作品。
# 1. 前面项目中定义画正方形的函数默认以 （0，0）为中心点，你能定义一个以任意点为中心画正方形的函数吗？
#
# 2. 根据画正方形、圆形的函数尝试组合画出更复杂的图形。
